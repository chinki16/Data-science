# %%
file="C:/Users/chink/Google Drive/Computational Statistics/5th Quater/Special Topics/JSM/histWeather.csv"
import pandas as pd

data=pd.read_csv(file,parse_dates=True,index_col='Date')
data.head()
# Out:
#             Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Date
# 2014-07-01              78.0               70.0              62.0
# 2014-07-02              77.0               70.0              64.0
# 2014-07-03              78.0               70.0              62.0
# 2014-07-04              77.0               70.0              62.0
# 2014-07-05              66.0               60.0              53.0
#
#             Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  \
# Date
# 2014-07-01            70.0            65.0           63.0         100.0
# 2014-07-02            70.0            66.0           63.0         100.0
# 2014-07-03            72.0            66.0           61.0         100.0
# 2014-07-04            70.0            66.0           61.0         100.0
# 2014-07-05            66.0            57.0           52.0         100.0
#
#             Mean_Humidity  Min_Humidity  Max_Sea_Level_PressureIn    ...      \
# ...

# %%
#Information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 130457 entries, 2014-07-01 to 2017-09-01
# Data columns (total 26 columns):
# Max_TemperatureF             130317 non-null float64
# Mean_TemperatureF            130308 non-null float64
# Min_TemperatureF             130317 non-null float64
# Max_Dew_PointF               130257 non-null float64
# MeanDew_PointF               130257 non-null float64
# Min_DewpointF                130257 non-null float64
# Max_Humidity                 130261 non-null float64
# Mean_Humidity                130261 non-null float64
# Min_Humidity                 130261 non-null float64
# Max_Sea_Level_PressureIn     130351 non-null float64
# Mean_Sea_Level_PressureIn    130351 non-null float64
# Min_Sea_Level_PressureIn     130351 non-null float64
# Max_VisibilityMiles          127915 non-null float64
# Mean_VisibilityMiles         127915 non-null float64
# Min_VisibilityMiles          127915 non-null float64
# ...

# %%
#Selecting perticular date
data.loc['2016-02-25']
# Out:
#             Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Date
# 2016-02-25              57.0               48.0              39.0
# 2016-02-25              54.0               45.0              35.0
# 2016-02-25              53.0               44.0              35.0
# 2016-02-25              62.0               52.0              41.0
# 2016-02-25              61.0               51.0              40.0
# 2016-02-25              63.0               50.0              36.0
# 2016-02-25              49.0               39.0              28.0
# 2016-02-25              64.0               50.0              35.0
# 2016-02-25              59.0               49.0              39.0
# 2016-02-25              58.0               46.0              33.0
# 2016-02-25              61.0               49.0              37.0
# 2016-02-25              61.0               51.0              40.0
# 2016-02-25              62.0               51.0              40.0
# ...

# %%
#Selecting AirPtCd col for data 12-13 feb
data.loc['2016-02-12':'2016-02-13','AirPtCd']
# Out:
# Date
# 2016-02-12    KBHB
# 2016-02-13    KBHB
# 2016-02-12    KBGR
# 2016-02-13    KBGR
# 2016-02-12    KPWM
# 2016-02-13    KPWM
# 2016-02-12    KBOS
# 2016-02-13    KBOS
# 2016-02-12    KPVD
# 2016-02-13    KPVD
# 2016-02-12    KMHT
# 2016-02-13    KMHT
# 2016-02-12    KMPV
# 2016-02-13    KMPV
# 2016-02-12    KCEF
# 2016-02-13    KCEF
# 2016-02-12    KHVN
# 2016-02-13    KHVN
# 2016-02-12    KALB
# 2016-02-13    KALB
# 2016-02-12    KNYC
# 2016-02-13    KNYC
# 2016-02-12    KACY
# 2016-02-13    KACY
# 2016-02-12    KPHL
# 2016-02-13    KPHL
# 2016-02-12    KDOV
# 2016-02-13    KDOV
# 2016-02-12    KAVP
# 2016-02-13    KAVP
#               ...
# 2016-02-12    KP68
# 2016-02-13    KP68
# 2016-02-12    KGEG
# 2016-02-13    KGEG
# 2016-02-12    KBKE
# 2016-02-13    KBKE
# 2016-02-12    KCQT
# 2016-02-13    KCQT
# 2016-02-12    KFAT
# 2016-02-13    KFAT
# 2016-02-12    KRNO
# 2016-02-13    KRNO
# 2016-02-12    KSAC
# 2016-02-13    KSAC
# 2016-02-12    KLMT
# 2016-02-13    KLMT
# ...

# %%
#Resmaple the time series data 'D' for daily
daily_mean=data.resample('D').mean()
daily_mean
# Out:
#             Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Date
# 2014-07-01         88.132743          77.053097         65.575221
# 2014-07-02         86.920354          76.353982         65.486726
# 2014-07-03         85.902655          74.761062         63.513274
# 2014-07-04         84.300885          73.716814         62.902655
# 2014-07-05         86.168142          74.424779         62.469027
# 2014-07-06         88.407080          76.451327         64.300885
# 2014-07-07         89.247788          78.026549         66.654867
# 2014-07-08         88.424779          77.805310         66.991150
# 2014-07-09         86.539823          76.159292         65.681416
# 2014-07-10         86.026786          75.553571         64.848214
# 2014-07-11         86.787611          75.867257         64.681416
# 2014-07-12         88.486726          76.805310         65.566372
# 2014-07-13         88.424779          78.150442         67.628319
# ...

# %%
#Hightest mean
data.resample('D').mean().max()
# Out:
# Max_TemperatureF             1897.017699
# Mean_TemperatureF              81.045045
# Min_TemperatureF               69.738739
# Max_Dew_PointF                 68.108108
# MeanDew_PointF                 64.360360
# Min_DewpointF                  60.252252
# Max_Humidity                   94.814159
# Mean_Humidity                  82.633929
# Min_Humidity                   69.026786
# Max_Sea_Level_PressureIn       30.588571
# Mean_Sea_Level_PressureIn      30.484107
# Min_Sea_Level_PressureIn       30.345714
# Max_VisibilityMiles            10.163636
# Mean_VisibilityMiles            9.909910
# Min_VisibilityMiles             9.009259
# Max_Wind_SpeedMPH              24.855856
# Mean_Wind_SpeedMPH             11.711712
# Max_Gust_SpeedMPH              35.274510
# CloudCover                      6.390909
# WindDirDegrees                248.000000
# longitude                     -95.241965
# latitude                       39.216513
# CityCode                       57.187500
# ...

# %%
#Count of monthly historical data
data.resample('M').count()
# Out:
#             Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Date
# 2014-07-31              3501               3501              3501
# 2014-08-31              3501               3501              3501
# 2014-09-30              3388               3388              3388
# 2014-10-31              3496               3496              3496
# 2014-11-30              3381               3381              3382
# 2014-12-31              3495               3494              3495
# 2015-01-31              3500               3500              3500
# 2015-02-28              3164               3164              3164
# 2015-03-31              3501               3501              3501
# 2015-04-30              3388               3387              3387
# 2015-05-31              3503               3503              3503
# 2015-06-30              3390               3390              3390
# 2015-07-31              3501               3501              3501
# ...

# %%
#Count of monthly historical data
data.resample('A').count()
# Out:
#             Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Date
# 2014-12-31             20762              20761             20763
# 2015-12-31             41158              41154             41157
# 2016-12-31             40893              40889             40893
# 2017-12-31             27504              27504             27504
#
#             Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  \
# Date
# 2014-12-31           20750           20750          20750         20751
# 2015-12-31           41130           41130          41130         41130
# 2016-12-31           40877           40877          40877         40880
# 2017-12-31           27500           27500          27500         27500
#
#             Mean_Humidity  Min_Humidity  Max_Sea_Level_PressureIn    ...      \
# Date                                                                 ...
# 2014-12-31          20751         20751                     20755    ...
# ...

# %%
#Converting upper case 
data['Events'].str.upper()
# Out:
# Date
# 2014-07-01                      NaN
# 2014-07-02                      NaN
# 2014-07-03                      NaN
# 2014-07-04                      NaN
# 2014-07-05                      NaN
# 2014-07-06                      NaN
# 2014-07-07                      NaN
# 2014-07-08                      NaN
# 2014-07-09                      NaN
# 2014-07-10                      NaN
# 2014-07-11                      NaN
# 2014-07-12                      NaN
# 2014-07-13                      NaN
# 2014-07-14                      NaN
# 2014-07-15                      NaN
# 2014-07-16             THUNDERSTORM
# 2014-07-17                      NaN
# 2014-07-18                      NaN
# 2014-07-19                      NaN
# 2014-07-20                      NaN
# 2014-07-21                      NaN
# 2014-07-22                      NaN
# 2014-07-23                      NaN
# 2014-07-24                      NaN
# 2014-07-25                      NaN
# 2014-07-26                      NaN
# ...

# %%
#Serching for a perticular events
data['Events'].str.contains('Rain')
# Out:
# Date
# 2014-07-01      NaN
# 2014-07-02      NaN
# 2014-07-03      NaN
# 2014-07-04      NaN
# 2014-07-05      NaN
# 2014-07-06      NaN
# 2014-07-07      NaN
# 2014-07-08      NaN
# 2014-07-09      NaN
# 2014-07-10      NaN
# 2014-07-11      NaN
# 2014-07-12      NaN
# 2014-07-13      NaN
# 2014-07-14      NaN
# 2014-07-15      NaN
# 2014-07-16    False
# 2014-07-17      NaN
# 2014-07-18      NaN
# 2014-07-19      NaN
# 2014-07-20      NaN
# 2014-07-21      NaN
# 2014-07-22      NaN
# 2014-07-23      NaN
# 2014-07-24      NaN
# 2014-07-25      NaN
# 2014-07-26      NaN
# 2014-07-27      NaN
# 2014-07-28      NaN
# 2014-07-29      NaN
# 2014-07-30      NaN
#               ...
# 2017-08-03      NaN
# 2017-08-04      NaN
# 2017-08-05     True
# 2017-08-06      NaN
# 2017-08-07      NaN
# 2017-08-08      NaN
# 2017-08-09      NaN
# 2017-08-10      NaN
# 2017-08-11     True
# 2017-08-12      NaN
# 2017-08-13      NaN
# 2017-08-14     True
# 2017-08-15     True
# 2017-08-16     True
# ...

# %%
#Numbers of column containing Rain in events 
data['Events'].str.contains('Rain').sum()
# Out:
# 39957

# %%
#Ploting Max_TemperatureF 
import matplotlib.pyplot as plt
data['Max_TemperatureF'].plot
plt.show()

# %%
#Ploting Max_TemperatureF for 2015
data.loc['2015','Max_TemperatureF'].plot(style='k.-')
plt.show()

# %%
#Ploting Max_TemperatureF and Min_TemperatureF for 2015 using subplot option
data.loc['2015',['Max_TemperatureF','Min_TemperatureF']].plot(subplots=True)
plt.show()
