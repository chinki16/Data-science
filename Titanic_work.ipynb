# %%
#Reading the dataset
import pandas as pd
import matplotlib.pyplot as mt
file='C:/Users/chink/Google Drive/Computational Statistics/Kaggle/Titanic/train.csv'
train=pd.read_csv(file)

# %%
#Getting heads of Dataset
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Getting heads of Dataset
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Gettings info 
train.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#Getting shape of Dataset
train.shape
# Out:
# (891, 12)

# %%
#Frequency of variables
train.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
#Summary Statistics
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Histogram of age 
train.Age.plot("hist")
mt.show()

# %%
#Subsetting Dataset
train[train.Age>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
#Boxplot of Age variable by Sex 
train.boxplot(column='Age',by='Sex',rot=45)
mt.show()

# %%
#Scatter plot of two variable
train.plot(kind='scatter',x='Age',y='Fare',rot=70)
mt.show()

# %%
#Tidy data
data1=train.pivot_table(index=['PassengerId','Pclass','Name','Sex','SibSp','Parch','Ticket','Cabin','Embarked'],columns='Survived',values=['Age','Fare'])

# %%
data1.head()
# Out:
#                                                                                                           Age  \
# Survived                                                                                                    0
# PassengerId Pclass Name                                               Sex    SibSp Parch Ticket   Cabin
# 2           1      Cumings, Mrs. John Bradley (Florence Briggs Tha... female 1     0     PC 17599 C85     NaN
# 4           1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 1     0     113803   C123    NaN
# 7           1      McCarthy, Mr. Timothy J                            male   0     0     17463    E46    54.0
# 11          3      Sandstrom, Miss. Marguerite Rut                    female 1     1     PP 9549  G6      NaN
# 12          1      Bonnell, Miss. Elizabeth                           female 0     0     113783   C103    NaN
#
# ...

# %%
#Tail of data
data1.tail()
# Out:
#                                                                                                                      Age  \
# Survived                                                                                                               0
# PassengerId Pclass Name                                             Sex    SibSp Parch Ticket Cabin       Embarked
# 872         1      Beckwith, Mrs. Richard Leonard (Sallie Monypeny) female 1     1     11751  D35         S          NaN
# 873         1      Carlsson, Mr. Frans Olof                         male   0     0     695    B51 B53 B55 S         33.0
# 880         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    female 0     1     11767  C50         C          NaN
# 888         1      Graham, Miss. Margaret Edith                     female 0     0     112053 B42         S          NaN
# 890         1      Behr, Mr. Karl Howell                            male   0     0     111369 C148        C          NaN
#
# ...
